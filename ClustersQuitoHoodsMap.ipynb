# %%
import pandas as pd

# %%
postal_codesdf=pd.read_excel(r"C:\Users\francisco.borja\Desktop\FB\Data Science\Coordenadas Codigos postales quito.xlsx")

# %%
postal_codesdf
# Out:
#     Código                       Lugar  Latitud  Longitud
# 0   170101        Alfaro (Chimbacalle) -0.23333 -78.51667
# 1   170102                  Benalcazar -0.18262 -78.48122
# 2   170103                  Cotocollao -0.11757 -78.49729
# 3   170104  Chaupicruz (La Concepcion) -0.15749 -78.48697
# 4   170105                 Chillogallo -0.31887 -78.57307
# ..     ...                         ...      ...       ...
# 81  170161                      Gualea  0.08360 -78.73982
# 82  170162                  Guangopolo -0.26735 -78.44616
# 83  170163                Guayllabamba -0.05862 -78.34185
# 84  170164                   La Merced -0.29261 -78.39918
# 85  170165                 Llano Chico -0.13333 -78.43333
#
# [86 rows x 4 columns]

# %%
postal_codesdf=pd.merge(postal_codesdf, coordinates, on='Postal Code')

# %%
print(postal_codesdf)
# Out:
#     Código                       Lugar  Latitud  Longitud
# 0   170101        Alfaro (Chimbacalle) -0.23333 -78.51667
# 1   170102                  Benalcazar -0.18262 -78.48122
# 2   170103                  Cotocollao -0.11757 -78.49729
# 3   170104  Chaupicruz (La Concepcion) -0.15749 -78.48697
# 4   170105                 Chillogallo -0.31887 -78.57307
# 5   170106                 El Salvador -0.16563 -78.51045
# 6   170107             Gonzalez Suarez -0.22197 -78.51239
# 7   170108                     Guapulo -0.20474 -78.47835
# 8   170109                 La Floresta -0.20909 -78.48348
# 9   170110                 La Libertad -0.27739 -78.57991
# 10  170111                La Magdalena -0.24360 -78.52990
# 11  170112                La Vicentina -0.21951 -78.48999
# 12  170113                    San Blas -0.22157 -78.50677
# 13  170114                  San Marcos -0.22525 -78.50820
# 14  170115                   San Roque -0.22092 -78.51656
# 15  170116               San Sebastian -0.22789 -78.51563
# 16  170117               Santa Barbara -0.27121 -78.56159
# 17  170118                Santa Prisca -0.21477 -78.50470
# 18  170119                  Villaflora -0.24461 -78.51859
# 19  170120                    Carcelen -0.08971 -78.46992
# 20  170121                 Chimbacalle -0.24820 -78.51566
# 21  170122                    El Batan -0.16735 -78.47303
# 22  170123                 El Beaterio -0.31814 -78.54385
# 23  170124                     El Inca -0.15803 -78.48183
# 24  170125                 Eloy Alfaro -0.16563 -78.51045
# 25  170126                     Guamani -0.33368 -78.55494
# 26  170127               La Concepción -0.22513 -78.52897
# 27  170128                 Las Cuadras -0.27948 -78.54895
# 28  170129           Belisario Quevedo -0.16563 -78.51045
# 29  170130            Centro Historico -0.27874 -78.55484
# 30  170131                   Chilibulo -0.24400 -78.53999
# 31  170132                  Cochapamba -0.15858 -78.50097
# 32  170133           Comite Del Pueblo -0.12176 -78.46588
# 33  170134                     Condado -0.10434 -78.50538
# 34  170135                    Iñaquito -0.16667 -78.50000
# 35  170136                   Itchimbia -0.22179 -78.50062
# 36  170137                    Jipijapa -0.16540 -78.48242
# 37  170138                     Kennedy -0.14037 -78.47811
# 38  170139                  La Argelia -0.16563 -78.51045
# 39  170140              La Ecuatoriana -0.30929 -78.56153
# 40  170141              La Ferroviaria -0.16563 -78.51045
# 41  170142                     La Mena -0.26431 -78.55013
# 42  170143              Mariscal Sucre -0.20549 -78.49511
# 43  170144                    Ponceano -0.16563 -78.51045
# 44  170145                    Puengasi -0.22662 -78.50654
# 45  170146                    Quitumbe -0.12336 -78.49223
# 46  170147                   Rumipamba -0.18270 -78.49366
# 47  170148                 San Bartolo -0.27779 -78.53327
# 48  170149         San Isidro Del Inca -0.14956 -78.47129
# 49  170150                       Quito -0.22950 -78.52428
# 50  170151                    Alangasi -0.30505 -78.41344
# 51  170152                    Amaguaña -0.38084 -78.51544
# 52  170179                      Puembo -0.17930 -78.36590
# 53  170180                 San Antonio -0.00800 -78.44535
# 54  170181           San Jose De Minas -0.15101 -78.46438
# 55  170182                Puerto Quito  0.11667 -79.26667
# 56  170183                    Tababela -0.18974 -78.34710
# 57  170184                     Tumbaco -0.21293 -78.40713
# 58  170185                     Yaruquì -0.16130 -78.32021
# 59  170186                     Zàmbiza -0.15424 -78.45775
# 60  170166                        Lloa -0.24490 -78.58899
# 61  170167                       Mindo -0.04892 -78.77557
# 62  170168                     Nanegal  0.13106 -78.67633
# 63  170169                  Nanegalito  0.06326 -78.68373
# 64  170170                       Nayón -0.16434 -78.45775
# 65  170171                        Nono -0.06481 -78.57752
# 66  170172                       Pacto  0.08175 -78.75893
# 67  170173     Pedro Vicente Maldonado  0.08333 -79.10000
# 68  170174                     Perucho  0.11385 -78.42561
# 69  170175                        Pifo -0.22593 -78.34313
# 70  170176                      Pintag -0.40828 -78.36542
# 71  170177                    Pomasqui -0.05830 -78.45976
# 72  170178                    Puellaro  0.06667 -78.40000
# 73  170153     Atahualpa (Chabaspamba) -0.18439 -78.49171
# 74  170154                    Calacali -0.00114 -78.51355
# 75  170155        Calderon (Carapungo) -0.09749 -78.42251
# 76  170156                    Conocoto -0.29239 -78.47662
# 77  170157                     Cumbaya -0.20006 -78.42893
# 78  170158                 Chavezpamba  0.13333 -78.38333
# 79  170159              Checa (Chilpa) -0.12664 -78.31173
# 80  170160                  El Quinche -0.11002 -78.29619
# 81  170161                      Gualea  0.08360 -78.73982
# 82  170162                  Guangopolo -0.26735 -78.44616
# 83  170163                Guayllabamba -0.05862 -78.34185
# 84  170164                   La Merced -0.29261 -78.39918
# 85  170165                 Llano Chico -0.13333 -78.43333

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# usage: conda [-h] [-V] command ...
# conda: error: unrecognized arguments: # uncomment this line if you haven't completed the Foursquare API lab
# Libraries imported.

# %%
CLIENT_ID = '3MVBMT1U052EZOYUHIZY20PNAFXP3HDKJUPZFO2HVYNFLW2D' # your Foursquare ID
CLIENT_SECRET = 'TGMWK2FTBXDMPF5VGORVNEQK4UF2NYEO0ZXK50ONPQHTNSHX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
LIMIT = 100 # limit of number of venues returned by Foursquare API



radius = 500 # define radius
# Out:
# Your credentails:
# CLIENT_ID: 3MVBMT1U052EZOYUHIZY20PNAFXP3HDKJUPZFO2HVYNFLW2D
# CLIENT_SECRET:TGMWK2FTBXDMPF5VGORVNEQK4UF2NYEO0ZXK50ONPQHTNSHX

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
   lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Quito_venues = getNearbyVenues(names=postal_codesdf['Lugar'],
                                   latitudes=postal_codesdf['Latitud'],
                                   longitudes=postal_codesdf['Longitud']
                                  )
# Out:
# Alfaro (Chimbacalle)
# Benalcazar
# Cotocollao
# Chaupicruz (La Concepcion)
# Chillogallo
# El Salvador
# Gonzalez Suarez
# Guapulo
# La Floresta
# La Libertad
# La Magdalena
# La Vicentina
# San Blas
# San Marcos
# San Roque
# San Sebastian
# Santa Barbara
# Santa Prisca
# Villaflora
# Carcelen
# Chimbacalle
# El Batan
# El Beaterio
# El Inca
# Eloy Alfaro
# Guamani
# La Concepción
# Las Cuadras
# Belisario Quevedo
# Centro Historico
# Chilibulo
# Cochapamba
# Comite Del Pueblo
# Condado
# Iñaquito
# Itchimbia
# Jipijapa
# Kennedy
# La Argelia
# La Ecuatoriana
# La Ferroviaria
# La Mena
# Mariscal Sucre
# Ponceano
# Puengasi
# Quitumbe
# Rumipamba
# San Bartolo
# San Isidro Del Inca
# Quito
# Alangasi
# Amaguaña
# Puembo
# San Antonio
# San Jose De Minas
# Puerto Quito
# Tababela
# Tumbaco
# Yaruquì
# Zàmbiza
# Lloa
# Mindo
# Nanegal
# Nanegalito
# Nayón
# Nono
# Pacto
# Pedro Vicente Maldonado
# Perucho
# Pifo
# Pintag
# Pomasqui
# Puellaro
# Atahualpa (Chabaspamba)
# Calacali
# Calderon (Carapungo)
# Conocoto
# Cumbaya
# Chavezpamba
# Checa (Chilpa)
# El Quinche
# Gualea
# Guangopolo
# Guayllabamba
# La Merced
# Llano Chico

# %%
print(Quito_venues.shape)
Quito_venues.head()
# Out:
# (632, 7)
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Alfaro (Chimbacalle)               -0.23333               -78.51667
# 1  Alfaro (Chimbacalle)               -0.23333               -78.51667
# 2  Alfaro (Chimbacalle)               -0.23333               -78.51667
# 3            Benalcazar               -0.18262               -78.48122
# 4            Benalcazar               -0.18262               -78.48122
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0  Museo Interactivo de Ciencia       -0.236313       -78.516309
# 1                           MIC       -0.231879       -78.515172
# 2          Mesón de la Recoleta       -0.231333       -78.512786
# 3                         Corfú       -0.181578       -78.481249
# 4                     Chicberry       -0.181021       -78.480118
#
#               Venue Category
# 0             Science Museum
# 1             Science Museum
# 2  South American Restaurant
# 3             Ice Cream Shop
# 4             Ice Cream Shop

# %%
Quito_venues.groupby('Neighborhood').count()
# Out:
# (632, 7)

# %%
print('There are {} uniques categories.'.format(Quito_venues['Venue Category'].unique()))
# Out:
# There are ['Science Museum' 'South American Restaurant' 'Ice Cream Shop'
#  'Coffee Shop' 'Pie Shop' 'Dessert Shop' 'Bagel Shop' 'Bakery'
#  'Italian Restaurant' 'French Restaurant' 'Hotel' 'Peruvian Restaurant'
#  'Creperie' 'Pizza Place' 'Sushi Restaurant' 'Diner' 'Salad Place'
#  'Pharmacy' 'Park' 'Japanese Restaurant' 'Burger Joint' 'Food Stand'
#  'Empanada Restaurant' 'Movie Theater' 'Multiplex' 'Sandwich Place'
#  'BBQ Joint' 'Argentinian Restaurant' 'Hotel Bar'
#  'Middle Eastern Restaurant' 'Gym / Fitness Center' 'Gastropub'
#  'Snack Place' 'Tex-Mex Restaurant' 'Supermarket' 'Playground'
#  'Convenience Store' 'Karaoke Bar' 'Korean Restaurant'
#  'Fast Food Restaurant' 'Cajun / Creole Restaurant' 'Butcher'
#  'Mediterranean Restaurant' 'Seafood Restaurant' 'Food Truck'
#  'Grocery Store' 'Restaurant' 'Mexican Restaurant' 'Bar'
#  'Asian Restaurant' 'Chinese Restaurant' 'Sculpture Garden'
#  'Fried Chicken Joint' 'Latin American Restaurant' 'Deli / Bodega'
#  'Paintball Field' 'Church' 'Art Gallery' 'Historic Site' 'Plaza'
#  'Breakfast Spot' 'History Museum' 'Cafeteria' 'Bed & Breakfast'
#  'Shopping Mall' 'Chocolate Shop' 'Café' 'Museum' 'Wine Bar' 'Bus Station'
#  'Southern / Soul Food Restaurant' 'Scenic Lookout' 'Wings Joint'
#  'Event Space' 'Lounge' 'Nightclub' 'Indie Movie Theater'
#  'Vietnamese Restaurant' 'Taco Place' 'Pub' 'Brewery' 'Spa'
#  'Spanish Restaurant' 'Boutique' 'Home Service' 'Theater' 'Hostel'
#  'Vegetarian / Vegan Restaurant' 'Farmers Market' 'Flea Market'
#  'Department Store' 'Art Museum' 'Gym' 'Soccer Field' 'Record Shop'
#  'Himalayan Restaurant' 'Bike Shop' 'Hot Dog Joint'
#  'Health & Beauty Service' 'Rental Car Location' 'Mobile Phone Shop'
#  'Food' 'Gift Shop' 'Toy / Game Store' 'Furniture / Home Store'
#  'Sporting Goods Shop' 'Monument / Landmark' 'Steakhouse' 'Clothing Store'
#  'Pool Hall' 'Brazilian Restaurant' 'Arepa Restaurant' 'Video Store'
#  'Gym Pool' 'Big Box Store' 'Gymnastics Gym' 'Liquor Store'
#  'Greek Restaurant' 'Arts & Crafts Store' 'Comedy Club' 'Food Court'
#  'Music Venue' 'Moving Target' 'Ski Trail' 'Recreation Center'
#  'Medical Supply Store' 'Food & Drink Shop' 'Rental Service' 'Rest Area'
#  'Farm' 'Go Kart Track' 'Arts & Entertainment' 'Resort' 'Lake'
#  'Cosmetics Shop' 'Trail' 'American Restaurant' 'Burrito Place'
#  'Pet Service' 'Campground' 'Martial Arts Dojo'] uniques categories.

# %%
# one hot encoding
quito_onehot = pd.get_dummies(Quito_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
quito_onehot['Neighborhood'] = Quito_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [quito_onehot.columns[-1]] + list(quito_onehot.columns[:-1])
quito_onehot = quito_onehot[fixed_columns]

quito_onehot.shape
# Out:
# (632, 142)

# %%
quito_grouped = quito_onehot.groupby('Neighborhood').mean().reset_index()
quito_grouped.shape
# Out:
# (67, 142)

# %%
num_top_venues = 5

for hood in quito_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = quito_grouped[quito_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Alangasi----
#            venue  freq
# 0   Soccer Field   0.5
# 1           Park   0.5
# 2  Moving Target   0.0
# 3      Multiplex   0.0
# 4         Museum   0.0
#
#
# ----Alfaro (Chimbacalle)----
#                        venue  freq
# 0             Science Museum  0.67
# 1  South American Restaurant  0.33
# 2                        Pub  0.00
# 3              Moving Target  0.00
# 4                  Multiplex  0.00
#
#
# ----Amaguaña----
#                  venue  freq
# 0            Ski Trail   1.0
# 1  American Restaurant   0.0
# 2                 Park   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----Atahualpa (Chabaspamba)----
#             venue  freq
# 0           Hotel  0.27
# 1             Bar  0.09
# 2  Cosmetics Shop  0.09
# 3        Pharmacy  0.09
# 4      Food Court  0.09
#
#
# ----Belisario Quevedo----
#                  venue  freq
# 0      Paintball Field   1.0
# 1  American Restaurant   0.0
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----Benalcazar----
#                 venue  freq
# 0  Italian Restaurant  0.09
# 1               Hotel  0.07
# 2         Coffee Shop  0.07
# 3              Bakery  0.06
# 4      Ice Cream Shop  0.04
#
#
# ----Calderon (Carapungo)----
#                  venue  freq
# 0                 Park  0.33
# 1          Pizza Place  0.33
# 2                  Bar  0.33
# 3  American Restaurant  0.00
# 4            Multiplex  0.00
#
#
# ----Carcelen----
#                   venue  freq
# 0           Bus Station  0.17
# 1           Pizza Place  0.17
# 2  Fast Food Restaurant  0.17
# 3                   Gym  0.17
# 4             BBQ Joint  0.17
#
#
# ----Centro Historico----
#                  venue  freq
# 0       Breakfast Spot  0.33
# 1          Pizza Place  0.33
# 2        Grocery Store  0.33
# 3  American Restaurant  0.00
# 4                 Park  0.00
#
#
# ----Chaupicruz (La Concepcion)----
#                 venue  freq
# 0          Restaurant  0.12
# 1                 Bar  0.06
# 2  Mexican Restaurant  0.06
# 3  Seafood Restaurant  0.06
# 4  Chinese Restaurant  0.06
#
#
# ----Chimbacalle----
#                   venue  freq
# 0           Record Shop  0.25
# 1                 Diner  0.25
# 2  Himalayan Restaurant  0.25
# 3   Fried Chicken Joint  0.25
# 4            Playground  0.00
#
#
# ----Cochapamba----
#                     venue  freq
# 0  Furniture / Home Store  0.36
# 1        Toy / Game Store  0.18
# 2             Record Shop  0.09
# 3          Ice Cream Shop  0.09
# 4          Sandwich Place  0.09
#
#
# ----Comite Del Pueblo----
#                        venue  freq
# 0                Wings Joint   0.5
# 1  Latin American Restaurant   0.5
# 2        Peruvian Restaurant   0.0
# 3                  Multiplex   0.0
# 4                     Museum   0.0
#
#
# ----Condado----
#            venue  freq
# 0       Creperie   0.5
# 1         Lounge   0.5
# 2  Movie Theater   0.0
# 3      Multiplex   0.0
# 4         Museum   0.0
#
#
# ----Conocoto----
#                  venue  freq
# 0           Restaurant  0.50
# 1        Grocery Store  0.25
# 2           Steakhouse  0.25
# 3  American Restaurant  0.00
# 4      Paintball Field  0.00
#
#
# ----Cotocollao----
#            venue  freq
# 0           Park  0.25
# 1   Burger Joint  0.25
# 2  Grocery Store  0.25
# 3     Food Truck  0.25
# 4      Multiplex  0.00
#
#
# ----Cumbaya----
#                        venue  freq
# 0                 Restaurant  0.09
# 1         Italian Restaurant  0.07
# 2  South American Restaurant  0.05
# 3             Ice Cream Shop  0.05
# 4                        Bar  0.05
#
#
# ----El Batan----
#                 venue  freq
# 0         Bus Station  0.11
# 1         Wings Joint  0.06
# 2           Bike Shop  0.06
# 3       Hot Dog Joint  0.06
# 4  Mexican Restaurant  0.06
#
#
# ----El Beaterio----
#                  venue  freq
# 0   Mexican Restaurant   1.0
# 1  American Restaurant   0.0
# 2        Movie Theater   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----El Inca----
#                  venue  freq
# 0         Burger Joint  0.12
# 1                  Bar  0.06
# 2          Coffee Shop  0.06
# 3    Mobile Phone Shop  0.06
# 4  Fried Chicken Joint  0.06
#
#
# ----El Quinche----
#                  venue  freq
# 0          Pet Service  0.25
# 1      Bed & Breakfast  0.25
# 2               Church  0.25
# 3             Pharmacy  0.25
# 4  Peruvian Restaurant  0.00
#
#
# ----El Salvador----
#                  venue  freq
# 0      Paintball Field   1.0
# 1  American Restaurant   0.0
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----Eloy Alfaro----
#                  venue  freq
# 0      Paintball Field   1.0
# 1  American Restaurant   0.0
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----Gonzalez Suarez----
#             venue  freq
# 0           Hotel  0.14
# 1      Restaurant  0.12
# 2  History Museum  0.07
# 3           Plaza  0.07
# 4     Coffee Shop  0.05
#
#
# ----Guapulo----
#                        venue  freq
# 0                Wings Joint  0.09
# 1                Pizza Place  0.09
# 2                  Nightclub  0.09
# 3  Latin American Restaurant  0.09
# 4         Italian Restaurant  0.09
#
#
# ----Guayllabamba----
#                        venue  freq
# 0                 Restaurant  0.33
# 1  Latin American Restaurant  0.33
# 2                       Park  0.33
# 3        American Restaurant  0.00
# 4        Peruvian Restaurant  0.00
#
#
# ----Itchimbia----
#                  venue  freq
# 0           Restaurant  0.38
# 1        Deli / Bodega  0.12
# 2  Monument / Landmark  0.12
# 3                 Café  0.12
# 4                 Park  0.12
#
#
# ----Iñaquito----
#                  venue  freq
# 0  Sporting Goods Shop   1.0
# 1  American Restaurant   0.0
# 2  Monument / Landmark   0.0
# 3        Moving Target   0.0
# 4            Multiplex   0.0
#
#
# ----Jipijapa----
#                 venue  freq
# 0  Seafood Restaurant  0.15
# 1           BBQ Joint  0.08
# 2        Burger Joint  0.08
# 3  Chinese Restaurant  0.06
# 4         Pizza Place  0.06
#
#
# ----Kennedy----
#                  venue  freq
# 0   Seafood Restaurant  0.33
# 1  Fried Chicken Joint  0.11
# 2   Chinese Restaurant  0.11
# 3       Farmers Market  0.11
# 4             Pharmacy  0.11
#
#
# ----La Argelia----
#                  venue  freq
# 0      Paintball Field   1.0
# 1  American Restaurant   0.0
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----La Ecuatoriana----
#                  venue  freq
# 0  Fried Chicken Joint  0.33
# 1        Big Box Store  0.33
# 2   Seafood Restaurant  0.33
# 3        Moving Target  0.00
# 4            Multiplex  0.00
#
#
# ----La Ferroviaria----
#                  venue  freq
# 0      Paintball Field   1.0
# 1  American Restaurant   0.0
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----La Floresta----
#                 venue  freq
# 0               Hotel  0.06
# 1    Sushi Restaurant  0.06
# 2  Italian Restaurant  0.06
# 3  Mexican Restaurant  0.06
# 4         Pizza Place  0.06
#
#
# ----La Magdalena----
#                        venue  freq
# 0                       Park   0.5
# 1  Latin American Restaurant   0.5
# 2        American Restaurant   0.0
# 3        Peruvian Restaurant   0.0
# 4                  Multiplex   0.0
#
#
# ----La Mena----
#             venue  freq
# 0  Gymnastics Gym  0.25
# 1    Liquor Store  0.25
# 2   Shopping Mall  0.25
# 3      Restaurant  0.25
# 4       Multiplex  0.00
#
#
# ----La Merced----
#                  venue  freq
# 0    Martial Arts Dojo   0.5
# 1           Campground   0.5
# 2  American Restaurant   0.0
# 3        Moving Target   0.0
# 4               Museum   0.0
#
#
# ----La Vicentina----
#                  venue  freq
# 0         Home Service  0.33
# 1             Boutique  0.33
# 2                 Park  0.33
# 3  American Restaurant  0.00
# 4  Peruvian Restaurant  0.00
#
#
# ----Las Cuadras----
#                  venue  freq
# 0                 Park  0.33
# 1  Fried Chicken Joint  0.33
# 2         Soccer Field  0.33
# 3           Playground  0.00
# 4          Pizza Place  0.00
#
#
# ----Mariscal Sucre----
#                        venue  freq
# 0                      Hotel  0.10
# 1                Coffee Shop  0.10
# 2                       Café  0.10
# 3  Middle Eastern Restaurant  0.10
# 4                Pizza Place  0.07
#
#
# ----Mindo----
#              venue  freq
# 0           Resort   0.2
# 1             Café   0.2
# 2             Lake   0.2
# 3      Pizza Place   0.2
# 4  Bed & Breakfast   0.2
#
#
# ----Nanegalito----
#                  venue  freq
# 0           Restaurant   0.5
# 1                 Food   0.5
# 2  American Restaurant   0.0
# 3                 Park   0.0
# 4            Multiplex   0.0
#
#
# ----Nayón----
#                  venue  freq
# 0               Bakery  0.67
# 1      Paintball Field  0.33
# 2  American Restaurant  0.00
# 3        Movie Theater  0.00
# 4            Multiplex  0.00
#
#
# ----Nono----
#                  venue  freq
# 0    Recreation Center   1.0
# 1  Peruvian Restaurant   0.0
# 2            Multiplex   0.0
# 3               Museum   0.0
# 4          Music Venue   0.0
#
#
# ----Pifo----
#                  venue  freq
# 0   Seafood Restaurant   1.0
# 1  American Restaurant   0.0
# 2                 Park   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----Pomasqui----
#                        venue  freq
# 0                Pizza Place  0.33
# 1  Cajun / Creole Restaurant  0.33
# 2                  BBQ Joint  0.33
# 3        American Restaurant  0.00
# 4        Peruvian Restaurant  0.00
#
#
# ----Ponceano----
#                  venue  freq
# 0      Paintball Field   1.0
# 1  American Restaurant   0.0
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----Puellaro----
#                  venue  freq
# 0                Plaza   1.0
# 1  American Restaurant   0.0
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----Puembo----
#                  venue  freq
# 0    Recreation Center   1.0
# 1  Peruvian Restaurant   0.0
# 2            Multiplex   0.0
# 3               Museum   0.0
# 4          Music Venue   0.0
#
#
# ----Puengasi----
#                  venue  freq
# 0          Bus Station  0.75
# 1                 Park  0.25
# 2  American Restaurant  0.00
# 3          Record Shop  0.00
# 4            Multiplex  0.00
#
#
# ----Quito----
#                  venue  freq
# 0        Moving Target  0.33
# 1        Historic Site  0.33
# 2                  Bar  0.33
# 3  Peruvian Restaurant  0.00
# 4            Multiplex  0.00
#
#
# ----Quitumbe----
#                  venue  freq
# 0          Pizza Place  0.33
# 1  Fried Chicken Joint  0.17
# 2         Burger Joint  0.08
# 3        Grocery Store  0.08
# 4           Restaurant  0.08
#
#
# ----Rumipamba----
#                  venue  freq
# 0   Mexican Restaurant  0.11
# 1                  Spa  0.11
# 2          Music Venue  0.11
# 3  Arts & Crafts Store  0.11
# 4          Pizza Place  0.11
#
#
# ----San Antonio----
#                   venue  freq
# 0        Ice Cream Shop   0.2
# 1        Rental Service   0.2
# 2           Pizza Place   0.2
# 3     Food & Drink Shop   0.2
# 4  Medical Supply Store   0.2
#
#
# ----San Bartolo----
#                venue  freq
# 0   Department Store   0.5
# 1  Convenience Store   0.5
# 2        Pet Service   0.0
# 3             Museum   0.0
# 4        Music Venue   0.0
#
#
# ----San Blas----
#         venue  freq
# 0  Restaurant  0.21
# 1       Plaza  0.07
# 2     Theater  0.07
# 3      Hostel  0.07
# 4       Hotel  0.03
#
#
# ----San Isidro Del Inca----
#                        venue  freq
# 0             Farmers Market   0.5
# 1  Latin American Restaurant   0.5
# 2        American Restaurant   0.0
# 3        Peruvian Restaurant   0.0
# 4                  Multiplex   0.0
#
#
# ----San Jose De Minas----
#                  venue  freq
# 0       Sandwich Place   0.5
# 1            Rest Area   0.5
# 2  Peruvian Restaurant   0.0
# 3            Multiplex   0.0
# 4               Museum   0.0
#
#
# ----San Marcos----
#          venue  freq
# 0  Bus Station  0.29
# 1        Diner  0.14
# 2          Bar  0.14
# 3      Brewery  0.14
# 4       Hostel  0.14
#
#
# ----San Roque----
#             venue  freq
# 0           Hotel  0.16
# 1  History Museum  0.12
# 2           Plaza  0.09
# 3      Restaurant  0.06
# 4          Church  0.06
#
#
# ----San Sebastian----
#                        venue  freq
# 0  Latin American Restaurant  0.14
# 1                 Restaurant  0.14
# 2             Scenic Lookout  0.14
# 3                       Park  0.07
# 4                   Wine Bar  0.07
#
#
# ----Santa Prisca----
#     venue  freq
# 0   Hotel   0.2
# 1  Church   0.2
# 2  Hostel   0.1
# 3    Park   0.1
# 4  Bakery   0.1
#
#
# ----Tababela----
#                  venue  freq
# 0               Hostel  0.33
# 1                 Farm  0.33
# 2      Bed & Breakfast  0.33
# 3  American Restaurant  0.00
# 4                 Park  0.00
#
#
# ----Tumbaco----
#            venue  freq
# 0          Plaza  0.17
# 1    Pizza Place  0.17
# 2    Coffee Shop  0.17
# 3  Go Kart Track  0.17
# 4     Restaurant  0.17
#
#
# ----Villaflora----
#                     venue  freq
# 0  Argentinian Restaurant  0.33
# 1             Pizza Place  0.17
# 2      Seafood Restaurant  0.17
# 3               BBQ Joint  0.17
# 4                  Lounge  0.17
#
#
# ----Yaruquì----
#                  venue  freq
# 0                 Farm  0.33
# 1           Restaurant  0.33
# 2            Cafeteria  0.33
# 3  American Restaurant  0.00
# 4  Peruvian Restaurant  0.00
#
#
# ----Zàmbiza----
#                   venue  freq
# 0                   Spa  0.25
# 1  Arts & Entertainment  0.25
# 2             Rest Area  0.25
# 3        Sandwich Place  0.25
# 4   American Restaurant  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = quito_grouped['Neighborhood']

for ind in np.arange(quito_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(quito_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#               Neighborhood 1st Most Common Venue      2nd Most Common Venue  \
# 0                 Alangasi          Soccer Field                       Park
# 1     Alfaro (Chimbacalle)        Science Museum  South American Restaurant
# 2                 Amaguaña             Ski Trail                Wings Joint
# 3  Atahualpa (Chabaspamba)                 Hotel                        Bar
# 4        Belisario Quevedo       Paintball Field                Wings Joint
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0        Farmers Market            Food Stand            Food Court
# 1            Food Truck            Food Stand            Food Court
# 2        Cosmetics Shop            Food Stand            Food Court
# 3    Mexican Restaurant            Food Court           Music Venue
# 4            Food Stand            Food Court     Food & Drink Shop
#
#   6th Most Common Venue      7th Most Common Venue      8th Most Common Venue  \
# 0     Food & Drink Shop                       Food                Flea Market
# 1     Food & Drink Shop                       Food                Flea Market
# 2     Food & Drink Shop                       Food                Flea Market
# 3              Pharmacy  Cajun / Creole Restaurant  South American Restaurant
# 4                  Food                Flea Market       Fast Food Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0  Fast Food Restaurant                   Farm
# 1  Fast Food Restaurant            Wings Joint
# 2  Fast Food Restaurant         Farmers Market
# 3        Cosmetics Shop              BBQ Joint
# 4        Farmers Market      French Restaurant

# %%
# set number of clusters
kclusters = 5

quito_grouped_clustering = quito_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(quito_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_.shape
# Out:
# (67,)

# %%
quito_merged = postal_codesdf

# merge quito_grouped with quito_data to add latitude/longitude for each neighborhood
quito_merged = quito_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Lugar')
quito_merged.head() # check the last columns!
quito_merged=quito_merged.dropna().reset_index()

quito_merged['Cluster Labels']=kmeans.labels_

# %%
address = 'Quito, Ecuador'
geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Quito are {}, {}.'.format(latitude, longitude))

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(quito_merged['Latitud'], quito_merged['Longitud'], quito_merged['Lugar'], quito_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
        
map_clusters
# Out:
# The geograpical coordinate of Quito are -0.2201641, -78.5123274.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.
